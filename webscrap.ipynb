# %%
pip install numpy
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting numpy
# ...
#   WARNING: The script f2py.exe is installed in 'c:\Users\harih\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 21.2.3; however, version 22.2.2 is available.
# You should consider upgrading via the 'c:\Users\harih\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 22.2.2 is available.
# You should consider upgrading via the 'c:\Users\harih\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('sample_metadata.csv')

# %%
x=data.iloc[:,1].values

# %%
pip install Selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 22.2.2 is available.
# You should consider upgrading via the 'c:\Users\harih\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
from selenium import webdriver
import time

# %%
for i in range(0,len(x)):
    print(x[i])
# Out:
# e394e9ec-7288-4ede-9ef8-41b631d100dd
# 931a50ff-3149-4c4a-9456-45ed3a9dd457
# 306f0222-8734-44ca-9a31-86e4e62b0a1b
# 7c831a1d-3253-4af4-a0ff-7fe9ff9af1ce
# 2db3c23d-c591-4ea0-b0a8-ed9c4343c80e
# 209e2e16-cb88-4a8f-9cdb-10e152caa26c
# 8970f713-4a7a-4125-892c-6a34139371d8
# 8632579e-d318-4dab-9994-d3945afc42ab
# 2a971e32-b0e7-4a3f-8c40-62d69c0307d8
# 5b7e557a-6aee-4077-b3cd-c96179e643ae
# 6cd8d2dd-5545-43b0-b796-ae0506d62eb8
# 67ba29e7-f294-4dcd-9630-ad768c22c588
# 7d8eab0a-e6c8-4449-9ebf-50c41db94a06
# c3b2c38d-81a3-42fd-a41e-6f6de3934007
# a091822c-447a-49a5-8c20-e329df79599c
# e6c8c5fc-158a-4de4-b3f6-3b645584bbc7
# 0956bc67-dd55-4c54-a56a-f22f2856662a
# ff9db03d-f81c-4079-8b05-f5a8c05b8cfe
# 654c6f5c-3e5c-49f0-b53f-87cd9797d7c9
# cb419344-6148-43d4-b549-570bd09b3e05
# 5793879b-f663-4a10-9bd9-1acd2e189650
# ac2cbce4-4ba8-42c9-ac61-70f42995588e
# 534f85f2-b9eb-45be-87d5-c3dffd13d541
# ac2cbce4-4ba8-42c9-ac61-70f42995588e
# 36eaf209-c332-4321-b6aa-51a3368ecd79
# ...

# %%
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

# %%
from selenium.common.exceptions import NoSuchElementException

# %%
driver = webdriver.Edge("msedgedriver")
s="https://portal.gdc.cancer.gov/cases/" + x[0]
driver.get(s)
time.sleep(3)
ne=driver.find_element(By.CSS_SELECTOR, "button[data-test='modal-cancel-button']" )
ne.click()

# %%
for i in range(0,len(x)):
    t=0
    s="https://portal.gdc.cancer.gov/cases/" + x[i]
    driver.get(s)
    time.sleep(5)
    ne=driver.find_element(By.CSS_SELECTOR, "body > div:nth-child(3) > div:nth-child(1) > div:nth-child(5) > span:nth-child(1) > div:nth-child(1) > div:nth-child(1) > div:nth-child(1) > div:nth-child(2) > div:nth-child(1) > div:nth-child(3) > span:nth-child(2) > div:nth-child(1) > span:nth-child(1) > div:nth-child(1) > div:nth-child(1) > div:nth-child(2) > table:nth-child(1) > tbody:nth-child(2) > tr:nth-child(4) > td:nth-child(2) > a:nth-child(1)" )
    ne.click()
    time.sleep(3)
    try:
        ne=driver.find_element(By.XPATH, "//a[contains(text(),'.rna_seq.genom')]" )
        ne.click()
        time.sleep(5)
        ne=driver.find_element(By.XPATH, "//a[contains(text(),'.rna_seq.augme')]" )
        ne.click()
        time.sleep(7)
        ne=driver.find_element(By.CSS_SELECTOR, ".test-download-button.button.css-917r8u")
        ne.click()
        time.sleep(5)
     
    except NoSuchElementException:
        driver.get(s)
        time.sleep(5)
        ne=driver.find_element(By.CSS_SELECTOR, "body > div:nth-child(3) > div:nth-child(1) > div:nth-child(5) > span:nth-child(1) > div:nth-child(1) > div:nth-child(1) > div:nth-child(1) > div:nth-child(2) > div:nth-child(1) > div:nth-child(3) > span:nth-child(2) > div:nth-child(1) > span:nth-child(1) > div:nth-child(1) > div:nth-child(1) > div:nth-child(2) > table:nth-child(1) > tbody:nth-child(2) > tr:nth-child(4) > td:nth-child(2) > a:nth-child(1)" )
        ne.click()
        time.sleep(3)
        try:
            ne=driver.find_element(By.XPATH, "//a[contains(text(),'.rna_seq.augme')]" )
            ne.click()
            time.sleep(7)
            ne=driver.find_element(By.CSS_SELECTOR, ".test-download-button.button.css-917r8u")
            ne.click()
            time.sleep(5)
        except NoSuchElementException:
            print(x[i])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_940/3873875658.py in <module>
#       2     t=0
#       3     s="https://portal.gdc.cancer.gov/cases/" + x[i]
# ----> 4     driver.get(s)
#       5     time.sleep(5)
#       6     ne=driver.find_element(By.CSS_SELECTOR, "body > div:nth-child(3) > div:nth-child(1) > div:nth-child(5) > span:nth-child(1) > div:nth-child(1) > div:nth-child(1) > div:nth-child(1) > div:nth-child(2) > div:nth-child(1) > div:nth-child(3) > span:nth-child(2) > div:nth-child(1) > span:nth-child(1) > div:nth-child(1) > div:nth-child(1) > div:nth-child(2) > table:nth-child(1) > tbody:nth-child(2) > tr:nth-child(4) > td:nth-child(2) > a:nth-child(1)" )
#
# c:\Users\harih\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
# ...
